# %%
#!/usr/bin/env python
"""
The Needleman-Wunsch Algorithm
==============================
This is a dynamic programming algorithm for finding the optimal alignment of
two strings.
Example
-------
    >>> x = "GATTACA"
    >>> y = "GCATGCU"
    >>> print(nw(x, y))
    G-ATTACA
    GCA-TGCU
LICENSE
This is free and unencumbered software released into the public domain.
Anyone is free to copy, modify, publish, use, compile, sell, or
distribute this software, either in source code form or as a compiled
binary, for any purpose, commercial or non-commercial, and by any
means.
In jurisdictions that recognize copyright laws, the author or authors
of this software dedicate any and all copyright interest in the
software to the public domain. We make this dedication for the benefit
of the public at large and to the detriment of our heirs and
successors. We intend this dedication to be an overt act of
relinquishment in perpetuity of all present and future rights to this
software under copyright law.
THE SOFTWARE IS PROVIDED "AS IS", WITHOUT WARRANTY OF ANY KIND,
EXPRESS OR IMPLIED, INCLUDING BUT NOT LIMITED TO THE WARRANTIES OF
MERCHANTABILITY, FITNESS FOR A PARTICULAR PURPOSE AND NONINFRINGEMENT.
IN NO EVENT SHALL THE AUTHORS BE LIABLE FOR ANY CLAIM, DAMAGES OR
OTHER LIABILITY, WHETHER IN AN ACTION OF CONTRACT, TORT OR OTHERWISE,
ARISING FROM, OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR
OTHER DEALINGS IN THE SOFTWARE.
For more information, please refer to <http://unlicense.org/>
"""

import numpy as np

def nw(x, y, match = 1, mismatch = 1, gap = 1):
    nx = len(x)
    ny = len(y)
    # Optimal score at each possible pair of characters.
    F = np.zeros((nx + 1, ny + 1))
    F[:,0] = np.linspace(0, -nx, nx + 1)
    F[0,:] = np.linspace(0, -ny, ny + 1)
    # Pointers to trace through an optimal aligment.
    P = np.zeros((nx + 1, ny + 1))
    P[:,0] = 3
    P[0,:] = 4
    # Temporary scores.
    t = np.zeros(3)
    for i in range(nx):
        for j in range(ny):
            if x[i] == y[j]:
                t[0] = F[i,j] + match
            else:
                t[0] = F[i,j] - mismatch
            t[1] = F[i,j+1] - gap
            t[2] = F[i+1,j] - gap
            tmax = np.max(t)
            F[i+1,j+1] = tmax
            if t[0] == tmax:
                P[i+1,j+1] += 2
            if t[1] == tmax:
                P[i+1,j+1] += 3
            if t[2] == tmax:
                P[i+1,j+1] += 4
    # Trace through an optimal alignment.
    i = nx
    j = ny
    rx = []
    ry = []
    while i > 0 or j > 0:
        if P[i,j] in [2, 5, 6, 9]:
            rx.append(x[i-1])
            ry.append(y[j-1])
            i -= 1
            j -= 1
        elif P[i,j] in [3, 5, 7, 9]:
            rx.append(x[i-1])
            ry.append('-')
            i -= 1
        elif P[i,j] in [4, 6, 7, 9]:
            rx.append('-')
            ry.append(y[j-1])
            j -= 1
    # Reverse the strings.
    rx = ''.join(rx)[::-1]
    ry = ''.join(ry)[::-1]
    return '\n'.join([rx, ry])

# %%
import pandas as pd

datos = pd.read_csv('dataframe.csv',sep=',')

# %%
datos
# Out:
#       Unnamed: 0   LanguageId   LanguageName  Latitude  Longitude  WordId  \
# 0              0  28001000000  Ref. Spelling -40.00000  -75.50000    1070
# 1              1  28131006609  Santa Bárbara -37.67405  -71.80186    1070
# 2              2  28131007109         Cañete -37.96722  -73.39282    1070
# 3              3  28131009109          Tirúa -38.36990  -73.49067    1070
# 4              4  28131009809   Alto Bío Bío -38.04457  -71.36344    1070
# ...          ...          ...            ...       ...        ...     ...
# 1336        1336  28261007209      Huiliches -39.63992  -71.18686   20610
# 1337        1337  28271006509      Jacobacci -41.28813  -69.55719   20610
# 1338        1338  28281000209       Cushamen -42.23392  -71.34994   20610
# 1339        1339  28281002209      Futaleufú -42.95052  -71.18351   20610
# 1340        1340  28281003209   Lago Rosario -43.24408  -71.32581   20610
#
#      WordModernName1          Phonetic SpellingAltv1        source_csv
# 0              ellos         fëjëŋɘn      feyengün  12-feyengün.csv
# 1              ellos     ˌvë.jë.ˈŋɘn           NaN  12-feyengün.csv
# 2              ellos      cʰɪ.ˈðwɪ.ŋɘn           NaN  12-feyengün.csv
# 3              ellos     ˈɸë.jë.ɣ̞ɐ̝           NaN  12-feyengün.csv
# 4              ellos  m̩.ˌvë.jë.ˈŋɘn           NaN  12-feyengün.csv
# ...              ...               ...           ...               ...
# 1336            vino           pʊl.ˈkʊ           NaN      9-pulkü.csv
# 1337            vino          ɸʊl.ˈkʰʊ           NaN      9-pulkü.csv
# 1338            vino         pʰʊl.ˈkʰʊ           NaN      9-pulkü.csv
# 1339            vino           ɸʊl.ˈxʊ           NaN      9-pulkü.csv
# 1340            vino           pʊl.ˈkʊ           NaN      9-pulkü.csv
#
# [1341 rows x 10 columns]

# %%
names = set(datos['LanguageName'])

# %%
names
# Out:
# {'Alto Bío Bío',
#  'Aluminé',
#  'Angol',
#  'Cañete',
#  'Chalileo',
#  'Chol Chol',
#  'Cunco',
#  'Curarrehue',
#  'Cushamen',
#  'Dollinco',
#  'Ercilla',
#  'Freire',
#  'Futaleufú',
#  'Galvarino',
#  'Huiliches',
#  'Icalma',
#  'Jacobacci',
#  'Junín de los Andes',
#  'Lago Rosario',
#  'Lanco',
#  'Lonquimay',
#  'Lumaco',
#  'Mariquina',
#  'Nueva Toltén',
#  'Panguipulli',
#  'Picunches',
#  'Puerto Saavedra',
#  'Ref. Spelling',
#  'S. Juan de la Costa',
#  'San Pablo',
#  'Santa Bárbara',
#  'Tirúa',
#  'Truf Truf',
#  'Valdivia',
#  'Victoria',
#  'Vilcún',
#  'Villarrica',
#  'Zapala'}

# %%
palabras = set(datos['WordModernName1'])

# %%
palabras
# Out:
# {'amigo',
#  'bajar',
#  'boca',
#  'bueno',
#  'cama',
#  'camino',
#  'campo',
#  'cochayuyo',
#  'cola',
#  'coser',
#  'cuerno',
#  'dia',
#  'ellos',
#  'estrella',
#  'fuego',
#  'grande',
#  'harina_tostada',
#  'hoja',
#  'lengua',
#  'lenya',
#  'llorar',
#  'luna',
#  'mano',
#  'matar',
#  'negro',
#  'noble',
#  'nombre',
#  'nube',
#  'persona_que_ensenya',
#  'pie',
#  'puerta',
#  'rojo',
#  'saber',
#  'sangre',
#  'sol',
#  'tengo_hambre',
#  'tres',
#  'vestido_lana',
#  'vino',
#  'zorro'}

# %%
palabras_elegidas = ['tres'] ## puedes agregar más

# %%
dict_datos = {L:{} for L in names}

# %%
for L in names:
    for word in palabras_elegidas:
        D = datos[datos['LanguageName']==L]
        try:
            dict_datos[L][word]=list(D[D['WordModernName1']==word]['Phonetic'])[0]
        except IndexError:
            pass#dict_datos[L][word]='unk'

# %%
set_palabras = []

for L in names:
    set_palabras+=[list(dict_datos[L].keys())]

# %%
set_palabras = list(set.intersection(*map(set,set_palabras)))

# %%
set_palabras
# Out:
# ['tres']

# %%
dict_datos = {name:{word:dict_datos[name][word] for word in set_palabras} for name in names}

# %%
dict_datos['San Pablo']
# Out:
# {'tres': 'ˈkʰɘ.lɐ̝'}

# %%
dict_datos['S. Juan de la Costa']
# Out:
# {'tres': 'ˈxɘ.lə'}

# %%
print(nw('f̞ë.jë.ˈŋɘn','ˈfëj.ŋɘn'))
# Out:
# -f̞ë.jë.ˈŋɘn
# ˈf-ë-j--.-ŋɘn

# %%
import itertools
pares_localidades = list(itertools.product(list(dict_datos.keys()), list(dict_datos.keys())))

# %%
pares_localidades
# Out:
# [('Icalma', 'Icalma'),
#  ('Icalma', 'Huiliches'),
#  ('Icalma', 'Villarrica'),
#  ('Icalma', 'Ercilla'),
#  ('Icalma', 'Chol Chol'),
#  ('Icalma', 'Cañete'),
#  ('Icalma', 'Cunco'),
#  ('Icalma', 'Ref. Spelling'),
#  ('Icalma', 'Chalileo'),
#  ('Icalma', 'Galvarino'),
#  ('Icalma', 'Puerto Saavedra'),
#  ('Icalma', 'Junín de los Andes'),
#  ('Icalma', 'Panguipulli'),
#  ('Icalma', 'Freire'),
#  ('Icalma', 'Alto Bío Bío'),
#  ('Icalma', 'Dollinco'),
#  ('Icalma', 'Nueva Toltén'),
#  ('Icalma', 'Victoria'),
#  ('Icalma', 'Lago Rosario'),
#  ('Icalma', 'Zapala'),
#  ('Icalma', 'Santa Bárbara'),
#  ('Icalma', 'Mariquina'),
#  ('Icalma', 'Tirúa'),
#  ('Icalma', 'S. Juan de la Costa'),
#  ('Icalma', 'Lumaco'),
#  ('Icalma', 'Vilcún'),
#  ('Icalma', 'Valdivia'),
#  ('Icalma', 'Futaleufú'),
#  ('Icalma', 'Curarrehue'),
#  ('Icalma', 'Jacobacci'),
#  ('Icalma', 'Picunches'),
#  ('Icalma', 'Lanco'),
#  ('Icalma', 'Aluminé'),
#  ('Icalma', 'Lonquimay'),
#  ('Icalma', 'Angol'),
#  ('Icalma', 'Cushamen'),
#  ('Icalma', 'Truf Truf'),
#  ('Icalma', 'San Pablo'),
#  ('Huiliches', 'Icalma'),
#  ('Huiliches', 'Huiliches'),
#  ('Huiliches', 'Villarrica'),
#  ('Huiliches', 'Ercilla'),
#  ('Huiliches', 'Chol Chol'),
#  ('Huiliches', 'Cañete'),
#  ('Huiliches', 'Cunco'),
#  ('Huiliches', 'Ref. Spelling'),
#  ('Huiliches', 'Chalileo'),
#  ('Huiliches', 'Galvarino'),
#  ('Huiliches', 'Puerto Saavedra'),
#  ('Huiliches', 'Junín de los Andes'),
#  ('Huiliches', 'Panguipulli'),
#  ('Huiliches', 'Freire'),
#  ('Huiliches', 'Alto Bío Bío'),
#  ('Huiliches', 'Dollinco'),
#  ('Huiliches', 'Nueva Toltén'),
#  ('Huiliches', 'Victoria'),
#  ('Huiliches', 'Lago Rosario'),
#  ('Huiliches', 'Zapala'),
#  ('Huiliches', 'Santa Bárbara'),
#  ('Huiliches', 'Mariquina'),
#  ('Huiliches', 'Tirúa'),
#  ('Huiliches', 'S. Juan de la Costa'),
#  ('Huiliches', 'Lumaco'),
#  ('Huiliches', 'Vilcún'),
#  ('Huiliches', 'Valdivia'),
#  ('Huiliches', 'Futaleufú'),
#  ('Huiliches', 'Curarrehue'),
#  ('Huiliches', 'Jacobacci'),
#  ('Huiliches', 'Picunches'),
#  ('Huiliches', 'Lanco'),
#  ('Huiliches', 'Aluminé'),
#  ('Huiliches', 'Lonquimay'),
#  ('Huiliches', 'Angol'),
#  ('Huiliches', 'Cushamen'),
#  ('Huiliches', 'Truf Truf'),
#  ('Huiliches', 'San Pablo'),
#  ('Villarrica', 'Icalma'),
#  ('Villarrica', 'Huiliches'),
#  ('Villarrica', 'Villarrica'),
#  ('Villarrica', 'Ercilla'),
#  ('Villarrica', 'Chol Chol'),
#  ('Villarrica', 'Cañete'),
#  ('Villarrica', 'Cunco'),
#  ('Villarrica', 'Ref. Spelling'),
#  ('Villarrica', 'Chalileo'),
#  ('Villarrica', 'Galvarino'),
#  ('Villarrica', 'Puerto Saavedra'),
#  ('Villarrica', 'Junín de los Andes'),
#  ('Villarrica', 'Panguipulli'),
#  ('Villarrica', 'Freire'),
#  ('Villarrica', 'Alto Bío Bío'),
#  ('Villarrica', 'Dollinco'),
#  ('Villarrica', 'Nueva Toltén'),
#  ('Villarrica', 'Victoria'),
#  ('Villarrica', 'Lago Rosario'),
#  ('Villarrica', 'Zapala'),
#  ('Villarrica', 'Santa Bárbara'),
#  ('Villarrica', 'Mariquina'),
#  ('Villarrica', 'Tirúa'),
#  ('Villarrica', 'S. Juan de la Costa'),
#  ('Villarrica', 'Lumaco'),
#  ('Villarrica', 'Vilcún'),
#  ('Villarrica', 'Valdivia'),
#  ('Villarrica', 'Futaleufú'),
#  ('Villarrica', 'Curarrehue'),
#  ('Villarrica', 'Jacobacci'),
#  ('Villarrica', 'Picunches'),
#  ('Villarrica', 'Lanco'),
#  ('Villarrica', 'Aluminé'),
#  ('Villarrica', 'Lonquimay'),
#  ('Villarrica', 'Angol'),
#  ('Villarrica', 'Cushamen'),
#  ('Villarrica', 'Truf Truf'),
#  ('Villarrica', 'San Pablo'),
#  ('Ercilla', 'Icalma'),
#  ('Ercilla', 'Huiliches'),
#  ('Ercilla', 'Villarrica'),
#  ('Ercilla', 'Ercilla'),
#  ('Ercilla', 'Chol Chol'),
#  ('Ercilla', 'Cañete'),
#  ('Ercilla', 'Cunco'),
#  ('Ercilla', 'Ref. Spelling'),
#  ('Ercilla', 'Chalileo'),
#  ('Ercilla', 'Galvarino'),
#  ('Ercilla', 'Puerto Saavedra'),
#  ('Ercilla', 'Junín de los Andes'),
#  ('Ercilla', 'Panguipulli'),
#  ('Ercilla', 'Freire'),
#  ('Ercilla', 'Alto Bío Bío'),
#  ('Ercilla', 'Dollinco'),
#  ('Ercilla', 'Nueva Toltén'),
#  ('Ercilla', 'Victoria'),
#  ('Ercilla', 'Lago Rosario'),
#  ('Ercilla', 'Zapala'),
#  ('Ercilla', 'Santa Bárbara'),
#  ('Ercilla', 'Mariquina'),
#  ('Ercilla', 'Tirúa'),
#  ('Ercilla', 'S. Juan de la Costa'),
#  ('Ercilla', 'Lumaco'),
#  ('Ercilla', 'Vilcún'),
#  ('Ercilla', 'Valdivia'),
#  ('Ercilla', 'Futaleufú'),
#  ('Ercilla', 'Curarrehue'),
#  ('Ercilla', 'Jacobacci'),
#  ('Ercilla', 'Picunches'),
#  ('Ercilla', 'Lanco'),
#  ('Ercilla', 'Aluminé'),
#  ('Ercilla', 'Lonquimay'),
#  ('Ercilla', 'Angol'),
#  ('Ercilla', 'Cushamen'),
#  ('Ercilla', 'Truf Truf'),
#  ('Ercilla', 'San Pablo'),
#  ('Chol Chol', 'Icalma'),
#  ('Chol Chol', 'Huiliches'),
#  ('Chol Chol', 'Villarrica'),
#  ('Chol Chol', 'Ercilla'),
#  ('Chol Chol', 'Chol Chol'),
#  ('Chol Chol', 'Cañete'),
#  ('Chol Chol', 'Cunco'),
#  ('Chol Chol', 'Ref. Spelling'),
#  ('Chol Chol', 'Chalileo'),
#  ('Chol Chol', 'Galvarino'),
#  ('Chol Chol', 'Puerto Saavedra'),
#  ('Chol Chol', 'Junín de los Andes'),
#  ('Chol Chol', 'Panguipulli'),
#  ('Chol Chol', 'Freire'),
#  ('Chol Chol', 'Alto Bío Bío'),
#  ('Chol Chol', 'Dollinco'),
#  ('Chol Chol', 'Nueva Toltén'),
#  ('Chol Chol', 'Victoria'),
#  ('Chol Chol', 'Lago Rosario'),
#  ('Chol Chol', 'Zapala'),
#  ('Chol Chol', 'Santa Bárbara'),
#  ('Chol Chol', 'Mariquina'),
#  ('Chol Chol', 'Tirúa'),
#  ('Chol Chol', 'S. Juan de la Costa'),
#  ('Chol Chol', 'Lumaco'),
#  ('Chol Chol', 'Vilcún'),
#  ('Chol Chol', 'Valdivia'),
#  ('Chol Chol', 'Futaleufú'),
#  ('Chol Chol', 'Curarrehue'),
#  ('Chol Chol', 'Jacobacci'),
#  ('Chol Chol', 'Picunches'),
#  ('Chol Chol', 'Lanco'),
#  ('Chol Chol', 'Aluminé'),
#  ('Chol Chol', 'Lonquimay'),
#  ('Chol Chol', 'Angol'),
#  ('Chol Chol', 'Cushamen'),
#  ('Chol Chol', 'Truf Truf'),
#  ('Chol Chol', 'San Pablo'),
#  ('Cañete', 'Icalma'),
#  ('Cañete', 'Huiliches'),
#  ('Cañete', 'Villarrica'),
#  ('Cañete', 'Ercilla'),
#  ('Cañete', 'Chol Chol'),
#  ('Cañete', 'Cañete'),
#  ('Cañete', 'Cunco'),
#  ('Cañete', 'Ref. Spelling'),
#  ('Cañete', 'Chalileo'),
#  ('Cañete', 'Galvarino'),
#  ('Cañete', 'Puerto Saavedra'),
#  ('Cañete', 'Junín de los Andes'),
#  ('Cañete', 'Panguipulli'),
#  ('Cañete', 'Freire'),
#  ('Cañete', 'Alto Bío Bío'),
#  ('Cañete', 'Dollinco'),
#  ('Cañete', 'Nueva Toltén'),
#  ('Cañete', 'Victoria'),
#  ('Cañete', 'Lago Rosario'),
#  ('Cañete', 'Zapala'),
#  ('Cañete', 'Santa Bárbara'),
#  ('Cañete', 'Mariquina'),
#  ('Cañete', 'Tirúa'),
#  ('Cañete', 'S. Juan de la Costa'),
#  ('Cañete', 'Lumaco'),
#  ('Cañete', 'Vilcún'),
#  ('Cañete', 'Valdivia'),
#  ('Cañete', 'Futaleufú'),
#  ('Cañete', 'Curarrehue'),
#  ('Cañete', 'Jacobacci'),
#  ('Cañete', 'Picunches'),
#  ('Cañete', 'Lanco'),
#  ('Cañete', 'Aluminé'),
#  ('Cañete', 'Lonquimay'),
#  ('Cañete', 'Angol'),
#  ('Cañete', 'Cushamen'),
#  ('Cañete', 'Truf Truf'),
#  ('Cañete', 'San Pablo'),
#  ('Cunco', 'Icalma'),
#  ('Cunco', 'Huiliches'),
#  ('Cunco', 'Villarrica'),
#  ('Cunco', 'Ercilla'),
#  ('Cunco', 'Chol Chol'),
#  ('Cunco', 'Cañete'),
#  ('Cunco', 'Cunco'),
#  ('Cunco', 'Ref. Spelling'),
#  ('Cunco', 'Chalileo'),
#  ('Cunco', 'Galvarino'),
#  ('Cunco', 'Puerto Saavedra'),
#  ('Cunco', 'Junín de los Andes'),
#  ('Cunco', 'Panguipulli'),
#  ('Cunco', 'Freire'),
#  ('Cunco', 'Alto Bío Bío'),
#  ('Cunco', 'Dollinco'),
#  ('Cunco', 'Nueva Toltén'),
#  ('Cunco', 'Victoria'),
#  ('Cunco', 'Lago Rosario'),
#  ('Cunco', 'Zapala'),
#  ('Cunco', 'Santa Bárbara'),
#  ('Cunco', 'Mariquina'),
#  ('Cunco', 'Tirúa'),
#  ('Cunco', 'S. Juan de la Costa'),
#  ('Cunco', 'Lumaco'),
#  ('Cunco', 'Vilcún'),
#  ('Cunco', 'Valdivia'),
#  ('Cunco', 'Futaleufú'),
#  ('Cunco', 'Curarrehue'),
#  ('Cunco', 'Jacobacci'),
#  ('Cunco', 'Picunches'),
#  ('Cunco', 'Lanco'),
#  ('Cunco', 'Aluminé'),
#  ('Cunco', 'Lonquimay'),
#  ('Cunco', 'Angol'),
#  ('Cunco', 'Cushamen'),
#  ('Cunco', 'Truf Truf'),
#  ('Cunco', 'San Pablo'),
#  ('Ref. Spelling', 'Icalma'),
#  ('Ref. Spelling', 'Huiliches'),
#  ('Ref. Spelling', 'Villarrica'),
#  ('Ref. Spelling', 'Ercilla'),
#  ('Ref. Spelling', 'Chol Chol'),
#  ('Ref. Spelling', 'Cañete'),
#  ('Ref. Spelling', 'Cunco'),
#  ('Ref. Spelling', 'Ref. Spelling'),
#  ('Ref. Spelling', 'Chalileo'),
#  ('Ref. Spelling', 'Galvarino'),
#  ('Ref. Spelling', 'Puerto Saavedra'),
#  ('Ref. Spelling', 'Junín de los Andes'),
#  ('Ref. Spelling', 'Panguipulli'),
#  ('Ref. Spelling', 'Freire'),
#  ('Ref. Spelling', 'Alto Bío Bío'),
#  ('Ref. Spelling', 'Dollinco'),
#  ('Ref. Spelling', 'Nueva Toltén'),
#  ('Ref. Spelling', 'Victoria'),
#  ('Ref. Spelling', 'Lago Rosario'),
#  ('Ref. Spelling', 'Zapala'),
#  ('Ref. Spelling', 'Santa Bárbara'),
#  ('Ref. Spelling', 'Mariquina'),
#  ('Ref. Spelling', 'Tirúa'),
#  ('Ref. Spelling', 'S. Juan de la Costa'),
#  ('Ref. Spelling', 'Lumaco'),
#  ('Ref. Spelling', 'Vilcún'),
#  ('Ref. Spelling', 'Valdivia'),
#  ('Ref. Spelling', 'Futaleufú'),
#  ('Ref. Spelling', 'Curarrehue'),
#  ('Ref. Spelling', 'Jacobacci'),
#  ('Ref. Spelling', 'Picunches'),
#  ('Ref. Spelling', 'Lanco'),
#  ('Ref. Spelling', 'Aluminé'),
#  ('Ref. Spelling', 'Lonquimay'),
#  ('Ref. Spelling', 'Angol'),
#  ('Ref. Spelling', 'Cushamen'),
#  ('Ref. Spelling', 'Truf Truf'),
#  ('Ref. Spelling', 'San Pablo'),
#  ('Chalileo', 'Icalma'),
#  ('Chalileo', 'Huiliches'),
#  ('Chalileo', 'Villarrica'),
#  ('Chalileo', 'Ercilla'),
#  ('Chalileo', 'Chol Chol'),
#  ('Chalileo', 'Cañete'),
#  ('Chalileo', 'Cunco'),
#  ('Chalileo', 'Ref. Spelling'),
#  ('Chalileo', 'Chalileo'),
#  ('Chalileo', 'Galvarino'),
#  ('Chalileo', 'Puerto Saavedra'),
#  ('Chalileo', 'Junín de los Andes'),
#  ('Chalileo', 'Panguipulli'),
#  ('Chalileo', 'Freire'),
#  ('Chalileo', 'Alto Bío Bío'),
#  ('Chalileo', 'Dollinco'),
#  ('Chalileo', 'Nueva Toltén'),
#  ('Chalileo', 'Victoria'),
#  ('Chalileo', 'Lago Rosario'),
#  ('Chalileo', 'Zapala'),
#  ('Chalileo', 'Santa Bárbara'),
#  ('Chalileo', 'Mariquina'),
#  ('Chalileo', 'Tirúa'),
#  ('Chalileo', 'S. Juan de la Costa'),
#  ('Chalileo', 'Lumaco'),
#  ('Chalileo', 'Vilcún'),
#  ('Chalileo', 'Valdivia'),
#  ('Chalileo', 'Futaleufú'),
#  ('Chalileo', 'Curarrehue'),
#  ('Chalileo', 'Jacobacci'),
#  ('Chalileo', 'Picunches'),
#  ('Chalileo', 'Lanco'),
#  ('Chalileo', 'Aluminé'),
#  ('Chalileo', 'Lonquimay'),
#  ('Chalileo', 'Angol'),
#  ('Chalileo', 'Cushamen'),
#  ('Chalileo', 'Truf Truf'),
#  ('Chalileo', 'San Pablo'),
#  ('Galvarino', 'Icalma'),
#  ('Galvarino', 'Huiliches'),
#  ('Galvarino', 'Villarrica'),
#  ('Galvarino', 'Ercilla'),
#  ('Galvarino', 'Chol Chol'),
#  ('Galvarino', 'Cañete'),
#  ('Galvarino', 'Cunco'),
#  ('Galvarino', 'Ref. Spelling'),
#  ('Galvarino', 'Chalileo'),
#  ('Galvarino', 'Galvarino'),
#  ('Galvarino', 'Puerto Saavedra'),
#  ('Galvarino', 'Junín de los Andes'),
#  ('Galvarino', 'Panguipulli'),
#  ('Galvarino', 'Freire'),
#  ('Galvarino', 'Alto Bío Bío'),
#  ('Galvarino', 'Dollinco'),
#  ('Galvarino', 'Nueva Toltén'),
#  ('Galvarino', 'Victoria'),
#  ('Galvarino', 'Lago Rosario'),
#  ('Galvarino', 'Zapala'),
#  ('Galvarino', 'Santa Bárbara'),
#  ('Galvarino', 'Mariquina'),
#  ('Galvarino', 'Tirúa'),
#  ('Galvarino', 'S. Juan de la Costa'),
#  ('Galvarino', 'Lumaco'),
#  ('Galvarino', 'Vilcún'),
#  ('Galvarino', 'Valdivia'),
#  ('Galvarino', 'Futaleufú'),
#  ('Galvarino', 'Curarrehue'),
#  ('Galvarino', 'Jacobacci'),
#  ('Galvarino', 'Picunches'),
#  ('Galvarino', 'Lanco'),
#  ('Galvarino', 'Aluminé'),
#  ('Galvarino', 'Lonquimay'),
#  ('Galvarino', 'Angol'),
#  ('Galvarino', 'Cushamen'),
#  ('Galvarino', 'Truf Truf'),
#  ('Galvarino', 'San Pablo'),
#  ('Puerto Saavedra', 'Icalma'),
#  ('Puerto Saavedra', 'Huiliches'),
#  ('Puerto Saavedra', 'Villarrica'),
#  ('Puerto Saavedra', 'Ercilla'),
#  ('Puerto Saavedra', 'Chol Chol'),
#  ('Puerto Saavedra', 'Cañete'),
#  ('Puerto Saavedra', 'Cunco'),
#  ('Puerto Saavedra', 'Ref. Spelling'),
#  ('Puerto Saavedra', 'Chalileo'),
#  ('Puerto Saavedra', 'Galvarino'),
#  ('Puerto Saavedra', 'Puerto Saavedra'),
#  ('Puerto Saavedra', 'Junín de los Andes'),
#  ('Puerto Saavedra', 'Panguipulli'),
#  ('Puerto Saavedra', 'Freire'),
#  ('Puerto Saavedra', 'Alto Bío Bío'),
#  ('Puerto Saavedra', 'Dollinco'),
#  ('Puerto Saavedra', 'Nueva Toltén'),
#  ('Puerto Saavedra', 'Victoria'),
#  ('Puerto Saavedra', 'Lago Rosario'),
#  ('Puerto Saavedra', 'Zapala'),
#  ('Puerto Saavedra', 'Santa Bárbara'),
#  ('Puerto Saavedra', 'Mariquina'),
#  ('Puerto Saavedra', 'Tirúa'),
#  ('Puerto Saavedra', 'S. Juan de la Costa'),
#  ('Puerto Saavedra', 'Lumaco'),
#  ('Puerto Saavedra', 'Vilcún'),
#  ('Puerto Saavedra', 'Valdivia'),
#  ('Puerto Saavedra', 'Futaleufú'),
#  ('Puerto Saavedra', 'Curarrehue'),
#  ('Puerto Saavedra', 'Jacobacci'),
#  ('Puerto Saavedra', 'Picunches'),
#  ('Puerto Saavedra', 'Lanco'),
#  ('Puerto Saavedra', 'Aluminé'),
#  ('Puerto Saavedra', 'Lonquimay'),
#  ('Puerto Saavedra', 'Angol'),
#  ('Puerto Saavedra', 'Cushamen'),
#  ('Puerto Saavedra', 'Truf Truf'),
#  ('Puerto Saavedra', 'San Pablo'),
#  ('Junín de los Andes', 'Icalma'),
#  ('Junín de los Andes', 'Huiliches'),
#  ('Junín de los Andes', 'Villarrica'),
#  ('Junín de los Andes', 'Ercilla'),
#  ('Junín de los Andes', 'Chol Chol'),
#  ('Junín de los Andes', 'Cañete'),
#  ('Junín de los Andes', 'Cunco'),
#  ('Junín de los Andes', 'Ref. Spelling'),
#  ('Junín de los Andes', 'Chalileo'),
#  ('Junín de los Andes', 'Galvarino'),
#  ('Junín de los Andes', 'Puerto Saavedra'),
#  ('Junín de los Andes', 'Junín de los Andes'),
#  ('Junín de los Andes', 'Panguipulli'),
#  ('Junín de los Andes', 'Freire'),
#  ('Junín de los Andes', 'Alto Bío Bío'),
#  ('Junín de los Andes', 'Dollinco'),
#  ('Junín de los Andes', 'Nueva Toltén'),
#  ('Junín de los Andes', 'Victoria'),
#  ('Junín de los Andes', 'Lago Rosario'),
#  ('Junín de los Andes', 'Zapala'),
#  ('Junín de los Andes', 'Santa Bárbara'),
#  ('Junín de los Andes', 'Mariquina'),
#  ('Junín de los Andes', 'Tirúa'),
#  ('Junín de los Andes', 'S. Juan de la Costa'),
#  ('Junín de los Andes', 'Lumaco'),
#  ('Junín de los Andes', 'Vilcún'),
#  ('Junín de los Andes', 'Valdivia'),
#  ('Junín de los Andes', 'Futaleufú'),
#  ('Junín de los Andes', 'Curarrehue'),
#  ('Junín de los Andes', 'Jacobacci'),
#  ('Junín de los Andes', 'Picunches'),
#  ('Junín de los Andes', 'Lanco'),
#  ('Junín de los Andes', 'Aluminé'),
#  ('Junín de los Andes', 'Lonquimay'),
#  ('Junín de los Andes', 'Angol'),
#  ('Junín de los Andes', 'Cushamen'),
#  ('Junín de los Andes', 'Truf Truf'),
#  ('Junín de los Andes', 'San Pablo'),
#  ('Panguipulli', 'Icalma'),
#  ('Panguipulli', 'Huiliches'),
#  ('Panguipulli', 'Villarrica'),
#  ('Panguipulli', 'Ercilla'),
#  ('Panguipulli', 'Chol Chol'),
#  ('Panguipulli', 'Cañete'),
#  ('Panguipulli', 'Cunco'),
#  ('Panguipulli', 'Ref. Spelling'),
#  ('Panguipulli', 'Chalileo'),
#  ('Panguipulli', 'Galvarino'),
#  ('Panguipulli', 'Puerto Saavedra'),
#  ('Panguipulli', 'Junín de los Andes'),
#  ('Panguipulli', 'Panguipulli'),
#  ('Panguipulli', 'Freire'),
#  ('Panguipulli', 'Alto Bío Bío'),
#  ('Panguipulli', 'Dollinco'),
#  ('Panguipulli', 'Nueva Toltén'),
#  ('Panguipulli', 'Victoria'),
#  ('Panguipulli', 'Lago Rosario'),
#  ('Panguipulli', 'Zapala'),
#  ('Panguipulli', 'Santa Bárbara'),
#  ('Panguipulli', 'Mariquina'),
#  ('Panguipulli', 'Tirúa'),
#  ('Panguipulli', 'S. Juan de la Costa'),
#  ('Panguipulli', 'Lumaco'),
#  ('Panguipulli', 'Vilcún'),
#  ('Panguipulli', 'Valdivia'),
#  ('Panguipulli', 'Futaleufú'),
#  ('Panguipulli', 'Curarrehue'),
#  ('Panguipulli', 'Jacobacci'),
#  ('Panguipulli', 'Picunches'),
#  ('Panguipulli', 'Lanco'),
#  ('Panguipulli', 'Aluminé'),
#  ('Panguipulli', 'Lonquimay'),
#  ('Panguipulli', 'Angol'),
#  ('Panguipulli', 'Cushamen'),
#  ('Panguipulli', 'Truf Truf'),
#  ('Panguipulli', 'San Pablo'),
#  ('Freire', 'Icalma'),
#  ('Freire', 'Huiliches'),
#  ('Freire', 'Villarrica'),
#  ('Freire', 'Ercilla'),
#  ('Freire', 'Chol Chol'),
#  ('Freire', 'Cañete'),
#  ('Freire', 'Cunco'),
#  ('Freire', 'Ref. Spelling'),
#  ('Freire', 'Chalileo'),
#  ('Freire', 'Galvarino'),
#  ('Freire', 'Puerto Saavedra'),
#  ('Freire', 'Junín de los Andes'),
#  ('Freire', 'Panguipulli'),
#  ('Freire', 'Freire'),
#  ('Freire', 'Alto Bío Bío'),
#  ('Freire', 'Dollinco'),
#  ('Freire', 'Nueva Toltén'),
#  ('Freire', 'Victoria'),
#  ('Freire', 'Lago Rosario'),
#  ('Freire', 'Zapala'),
#  ('Freire', 'Santa Bárbara'),
#  ('Freire', 'Mariquina'),
#  ('Freire', 'Tirúa'),
#  ('Freire', 'S. Juan de la Costa'),
#  ('Freire', 'Lumaco'),
#  ('Freire', 'Vilcún'),
#  ('Freire', 'Valdivia'),
#  ('Freire', 'Futaleufú'),
#  ('Freire', 'Curarrehue'),
#  ('Freire', 'Jacobacci'),
#  ('Freire', 'Picunches'),
#  ('Freire', 'Lanco'),
#  ('Freire', 'Aluminé'),
#  ('Freire', 'Lonquimay'),
#  ('Freire', 'Angol'),
#  ('Freire', 'Cushamen'),
#  ('Freire', 'Truf Truf'),
#  ('Freire', 'San Pablo'),
#  ('Alto Bío Bío', 'Icalma'),
#  ('Alto Bío Bío', 'Huiliches'),
#  ('Alto Bío Bío', 'Villarrica'),
#  ('Alto Bío Bío', 'Ercilla'),
#  ('Alto Bío Bío', 'Chol Chol'),
#  ('Alto Bío Bío', 'Cañete'),
#  ('Alto Bío Bío', 'Cunco'),
#  ('Alto Bío Bío', 'Ref. Spelling'),
#  ('Alto Bío Bío', 'Chalileo'),
#  ('Alto Bío Bío', 'Galvarino'),
#  ('Alto Bío Bío', 'Puerto Saavedra'),
#  ('Alto Bío Bío', 'Junín de los Andes'),
#  ('Alto Bío Bío', 'Panguipulli'),
#  ('Alto Bío Bío', 'Freire'),
#  ('Alto Bío Bío', 'Alto Bío Bío'),
#  ('Alto Bío Bío', 'Dollinco'),
#  ('Alto Bío Bío', 'Nueva Toltén'),
#  ('Alto Bío Bío', 'Victoria'),
#  ('Alto Bío Bío', 'Lago Rosario'),
#  ('Alto Bío Bío', 'Zapala'),
#  ('Alto Bío Bío', 'Santa Bárbara'),
#  ('Alto Bío Bío', 'Mariquina'),
#  ('Alto Bío Bío', 'Tirúa'),
#  ('Alto Bío Bío', 'S. Juan de la Costa'),
#  ('Alto Bío Bío', 'Lumaco'),
#  ('Alto Bío Bío', 'Vilcún'),
#  ('Alto Bío Bío', 'Valdivia'),
#  ('Alto Bío Bío', 'Futaleufú'),
#  ('Alto Bío Bío', 'Curarrehue'),
#  ('Alto Bío Bío', 'Jacobacci'),
#  ('Alto Bío Bío', 'Picunches'),
#  ('Alto Bío Bío', 'Lanco'),
#  ('Alto Bío Bío', 'Aluminé'),
#  ('Alto Bío Bío', 'Lonquimay'),
#  ('Alto Bío Bío', 'Angol'),
#  ('Alto Bío Bío', 'Cushamen'),
#  ('Alto Bío Bío', 'Truf Truf'),
#  ('Alto Bío Bío', 'San Pablo'),
#  ('Dollinco', 'Icalma'),
#  ('Dollinco', 'Huiliches'),
#  ('Dollinco', 'Villarrica'),
#  ('Dollinco', 'Ercilla'),
#  ('Dollinco', 'Chol Chol'),
#  ('Dollinco', 'Cañete'),
#  ('Dollinco', 'Cunco'),
#  ('Dollinco', 'Ref. Spelling'),
#  ('Dollinco', 'Chalileo'),
#  ('Dollinco', 'Galvarino'),
#  ('Dollinco', 'Puerto Saavedra'),
#  ('Dollinco', 'Junín de los Andes'),
#  ('Dollinco', 'Panguipulli'),
#  ('Dollinco', 'Freire'),
#  ('Dollinco', 'Alto Bío Bío'),
#  ('Dollinco', 'Dollinco'),
#  ('Dollinco', 'Nueva Toltén'),
#  ('Dollinco', 'Victoria'),
#  ('Dollinco', 'Lago Rosario'),
#  ('Dollinco', 'Zapala'),
#  ('Dollinco', 'Santa Bárbara'),
#  ('Dollinco', 'Mariquina'),
#  ('Dollinco', 'Tirúa'),
#  ('Dollinco', 'S. Juan de la Costa'),
#  ('Dollinco', 'Lumaco'),
#  ('Dollinco', 'Vilcún'),
#  ('Dollinco', 'Valdivia'),
#  ('Dollinco', 'Futaleufú'),
#  ('Dollinco', 'Curarrehue'),
#  ('Dollinco', 'Jacobacci'),
#  ('Dollinco', 'Picunches'),
#  ('Dollinco', 'Lanco'),
#  ('Dollinco', 'Aluminé'),
#  ('Dollinco', 'Lonquimay'),
#  ('Dollinco', 'Angol'),
#  ('Dollinco', 'Cushamen'),
#  ('Dollinco', 'Truf Truf'),
#  ('Dollinco', 'San Pablo'),
#  ('Nueva Toltén', 'Icalma'),
#  ('Nueva Toltén', 'Huiliches'),
#  ('Nueva Toltén', 'Villarrica'),
#  ('Nueva Toltén', 'Ercilla'),
#  ('Nueva Toltén', 'Chol Chol'),
#  ('Nueva Toltén', 'Cañete'),
#  ('Nueva Toltén', 'Cunco'),
#  ('Nueva Toltén', 'Ref. Spelling'),
#  ('Nueva Toltén', 'Chalileo'),
#  ('Nueva Toltén', 'Galvarino'),
#  ('Nueva Toltén', 'Puerto Saavedra'),
#  ('Nueva Toltén', 'Junín de los Andes'),
#  ('Nueva Toltén', 'Panguipulli'),
#  ('Nueva Toltén', 'Freire'),
#  ('Nueva Toltén', 'Alto Bío Bío'),
#  ('Nueva Toltén', 'Dollinco'),
#  ('Nueva Toltén', 'Nueva Toltén'),
#  ('Nueva Toltén', 'Victoria'),
#  ('Nueva Toltén', 'Lago Rosario'),
#  ('Nueva Toltén', 'Zapala'),
#  ('Nueva Toltén', 'Santa Bárbara'),
#  ('Nueva Toltén', 'Mariquina'),
#  ('Nueva Toltén', 'Tirúa'),
#  ('Nueva Toltén', 'S. Juan de la Costa'),
#  ('Nueva Toltén', 'Lumaco'),
#  ('Nueva Toltén', 'Vilcún'),
#  ('Nueva Toltén', 'Valdivia'),
#  ('Nueva Toltén', 'Futaleufú'),
#  ('Nueva Toltén', 'Curarrehue'),
#  ('Nueva Toltén', 'Jacobacci'),
#  ('Nueva Toltén', 'Picunches'),
#  ('Nueva Toltén', 'Lanco'),
#  ('Nueva Toltén', 'Aluminé'),
#  ('Nueva Toltén', 'Lonquimay'),
#  ('Nueva Toltén', 'Angol'),
#  ('Nueva Toltén', 'Cushamen'),
#  ('Nueva Toltén', 'Truf Truf'),
#  ('Nueva Toltén', 'San Pablo'),
#  ('Victoria', 'Icalma'),
#  ('Victoria', 'Huiliches'),
#  ('Victoria', 'Villarrica'),
#  ('Victoria', 'Ercilla'),
#  ('Victoria', 'Chol Chol'),
#  ('Victoria', 'Cañete'),
#  ('Victoria', 'Cunco'),
#  ('Victoria', 'Ref. Spelling'),
#  ('Victoria', 'Chalileo'),
#  ('Victoria', 'Galvarino'),
#  ('Victoria', 'Puerto Saavedra'),
#  ('Victoria', 'Junín de los Andes'),
#  ('Victoria', 'Panguipulli'),
#  ('Victoria', 'Freire'),
#  ('Victoria', 'Alto Bío Bío'),
#  ('Victoria', 'Dollinco'),
#  ('Victoria', 'Nueva Toltén'),
#  ('Victoria', 'Victoria'),
#  ('Victoria', 'Lago Rosario'),
#  ('Victoria', 'Zapala'),
#  ('Victoria', 'Santa Bárbara'),
#  ('Victoria', 'Mariquina'),
#  ('Victoria', 'Tirúa'),
#  ('Victoria', 'S. Juan de la Costa'),
#  ('Victoria', 'Lumaco'),
#  ('Victoria', 'Vilcún'),
#  ('Victoria', 'Valdivia'),
#  ('Victoria', 'Futaleufú'),
#  ('Victoria', 'Curarrehue'),
#  ('Victoria', 'Jacobacci'),
#  ('Victoria', 'Picunches'),
#  ('Victoria', 'Lanco'),
#  ('Victoria', 'Aluminé'),
#  ('Victoria', 'Lonquimay'),
#  ('Victoria', 'Angol'),
#  ('Victoria', 'Cushamen'),
#  ('Victoria', 'Truf Truf'),
#  ('Victoria', 'San Pablo'),
#  ('Lago Rosario', 'Icalma'),
#  ('Lago Rosario', 'Huiliches'),
#  ('Lago Rosario', 'Villarrica'),
#  ('Lago Rosario', 'Ercilla'),
#  ('Lago Rosario', 'Chol Chol'),
#  ('Lago Rosario', 'Cañete'),
#  ('Lago Rosario', 'Cunco'),
#  ('Lago Rosario', 'Ref. Spelling'),
#  ('Lago Rosario', 'Chalileo'),
#  ('Lago Rosario', 'Galvarino'),
#  ('Lago Rosario', 'Puerto Saavedra'),
#  ('Lago Rosario', 'Junín de los Andes'),
#  ('Lago Rosario', 'Panguipulli'),
#  ('Lago Rosario', 'Freire'),
#  ('Lago Rosario', 'Alto Bío Bío'),
#  ('Lago Rosario', 'Dollinco'),
#  ('Lago Rosario', 'Nueva Toltén'),
#  ('Lago Rosario', 'Victoria'),
#  ('Lago Rosario', 'Lago Rosario'),
#  ('Lago Rosario', 'Zapala'),
#  ('Lago Rosario', 'Santa Bárbara'),
#  ('Lago Rosario', 'Mariquina'),
#  ('Lago Rosario', 'Tirúa'),
#  ('Lago Rosario', 'S. Juan de la Costa'),
#  ('Lago Rosario', 'Lumaco'),
#  ('Lago Rosario', 'Vilcún'),
#  ('Lago Rosario', 'Valdivia'),
#  ('Lago Rosario', 'Futaleufú'),
#  ('Lago Rosario', 'Curarrehue'),
#  ('Lago Rosario', 'Jacobacci'),
#  ('Lago Rosario', 'Picunches'),
#  ('Lago Rosario', 'Lanco'),
#  ('Lago Rosario', 'Aluminé'),
#  ('Lago Rosario', 'Lonquimay'),
#  ('Lago Rosario', 'Angol'),
#  ('Lago Rosario', 'Cushamen'),
#  ('Lago Rosario', 'Truf Truf'),
#  ('Lago Rosario', 'San Pablo'),
#  ('Zapala', 'Icalma'),
#  ('Zapala', 'Huiliches'),
#  ('Zapala', 'Villarrica'),
#  ('Zapala', 'Ercilla'),
#  ('Zapala', 'Chol Chol'),
#  ('Zapala', 'Cañete'),
#  ('Zapala', 'Cunco'),
#  ('Zapala', 'Ref. Spelling'),
#  ('Zapala', 'Chalileo'),
#  ('Zapala', 'Galvarino'),
#  ('Zapala', 'Puerto Saavedra'),
#  ('Zapala', 'Junín de los Andes'),
#  ('Zapala', 'Panguipulli'),
#  ('Zapala', 'Freire'),
#  ('Zapala', 'Alto Bío Bío'),
#  ('Zapala', 'Dollinco'),
#  ('Zapala', 'Nueva Toltén'),
#  ('Zapala', 'Victoria'),
#  ('Zapala', 'Lago Rosario'),
#  ('Zapala', 'Zapala'),
#  ('Zapala', 'Santa Bárbara'),
#  ('Zapala', 'Mariquina'),
#  ('Zapala', 'Tirúa'),
#  ('Zapala', 'S. Juan de la Costa'),
#  ('Zapala', 'Lumaco'),
#  ('Zapala', 'Vilcún'),
#  ('Zapala', 'Valdivia'),
#  ('Zapala', 'Futaleufú'),
#  ('Zapala', 'Curarrehue'),
#  ('Zapala', 'Jacobacci'),
#  ('Zapala', 'Picunches'),
#  ('Zapala', 'Lanco'),
#  ('Zapala', 'Aluminé'),
#  ('Zapala', 'Lonquimay'),
#  ('Zapala', 'Angol'),
#  ('Zapala', 'Cushamen'),
#  ('Zapala', 'Truf Truf'),
#  ('Zapala', 'San Pablo'),
#  ('Santa Bárbara', 'Icalma'),
#  ('Santa Bárbara', 'Huiliches'),
#  ('Santa Bárbara', 'Villarrica'),
#  ('Santa Bárbara', 'Ercilla'),
#  ('Santa Bárbara', 'Chol Chol'),
#  ('Santa Bárbara', 'Cañete'),
#  ('Santa Bárbara', 'Cunco'),
#  ('Santa Bárbara', 'Ref. Spelling'),
#  ('Santa Bárbara', 'Chalileo'),
#  ('Santa Bárbara', 'Galvarino'),
#  ('Santa Bárbara', 'Puerto Saavedra'),
#  ('Santa Bárbara', 'Junín de los Andes'),
#  ('Santa Bárbara', 'Panguipulli'),
#  ('Santa Bárbara', 'Freire'),
#  ('Santa Bárbara', 'Alto Bío Bío'),
#  ('Santa Bárbara', 'Dollinco'),
#  ('Santa Bárbara', 'Nueva Toltén'),
#  ('Santa Bárbara', 'Victoria'),
#  ('Santa Bárbara', 'Lago Rosario'),
#  ('Santa Bárbara', 'Zapala'),
#  ('Santa Bárbara', 'Santa Bárbara'),
#  ('Santa Bárbara', 'Mariquina'),
#  ('Santa Bárbara', 'Tirúa'),
#  ('Santa Bárbara', 'S. Juan de la Costa'),
#  ('Santa Bárbara', 'Lumaco'),
#  ('Santa Bárbara', 'Vilcún'),
#  ('Santa Bárbara', 'Valdivia'),
#  ('Santa Bárbara', 'Futaleufú'),
#  ('Santa Bárbara', 'Curarrehue'),
#  ('Santa Bárbara', 'Jacobacci'),
#  ('Santa Bárbara', 'Picunches'),
#  ('Santa Bárbara', 'Lanco'),
#  ('Santa Bárbara', 'Aluminé'),
#  ('Santa Bárbara', 'Lonquimay'),
#  ('Santa Bárbara', 'Angol'),
#  ('Santa Bárbara', 'Cushamen'),
#  ('Santa Bárbara', 'Truf Truf'),
#  ('Santa Bárbara', 'San Pablo'),
#  ('Mariquina', 'Icalma'),
#  ('Mariquina', 'Huiliches'),
#  ('Mariquina', 'Villarrica'),
#  ('Mariquina', 'Ercilla'),
#  ('Mariquina', 'Chol Chol'),
#  ('Mariquina', 'Cañete'),
#  ('Mariquina', 'Cunco'),
#  ('Mariquina', 'Ref. Spelling'),
#  ('Mariquina', 'Chalileo'),
#  ('Mariquina', 'Galvarino'),
#  ('Mariquina', 'Puerto Saavedra'),
#  ('Mariquina', 'Junín de los Andes'),
#  ('Mariquina', 'Panguipulli'),
#  ('Mariquina', 'Freire'),
#  ('Mariquina', 'Alto Bío Bío'),
#  ('Mariquina', 'Dollinco'),
#  ('Mariquina', 'Nueva Toltén'),
#  ('Mariquina', 'Victoria'),
#  ('Mariquina', 'Lago Rosario'),
#  ('Mariquina', 'Zapala'),
#  ('Mariquina', 'Santa Bárbara'),
#  ('Mariquina', 'Mariquina'),
#  ('Mariquina', 'Tirúa'),
#  ('Mariquina', 'S. Juan de la Costa'),
#  ('Mariquina', 'Lumaco'),
#  ('Mariquina', 'Vilcún'),
#  ('Mariquina', 'Valdivia'),
#  ('Mariquina', 'Futaleufú'),
#  ('Mariquina', 'Curarrehue'),
#  ('Mariquina', 'Jacobacci'),
#  ('Mariquina', 'Picunches'),
#  ('Mariquina', 'Lanco'),
#  ('Mariquina', 'Aluminé'),
#  ('Mariquina', 'Lonquimay'),
#  ('Mariquina', 'Angol'),
#  ('Mariquina', 'Cushamen'),
#  ('Mariquina', 'Truf Truf'),
#  ('Mariquina', 'San Pablo'),
#  ('Tirúa', 'Icalma'),
#  ('Tirúa', 'Huiliches'),
#  ('Tirúa', 'Villarrica'),
#  ('Tirúa', 'Ercilla'),
#  ('Tirúa', 'Chol Chol'),
#  ('Tirúa', 'Cañete'),
#  ('Tirúa', 'Cunco'),
#  ('Tirúa', 'Ref. Spelling'),
#  ('Tirúa', 'Chalileo'),
#  ('Tirúa', 'Galvarino'),
#  ('Tirúa', 'Puerto Saavedra'),
#  ('Tirúa', 'Junín de los Andes'),
#  ('Tirúa', 'Panguipulli'),
#  ('Tirúa', 'Freire'),
#  ('Tirúa', 'Alto Bío Bío'),
#  ('Tirúa', 'Dollinco'),
#  ('Tirúa', 'Nueva Toltén'),
#  ('Tirúa', 'Victoria'),
#  ('Tirúa', 'Lago Rosario'),
#  ('Tirúa', 'Zapala'),
#  ('Tirúa', 'Santa Bárbara'),
#  ('Tirúa', 'Mariquina'),
#  ('Tirúa', 'Tirúa'),
#  ('Tirúa', 'S. Juan de la Costa'),
#  ('Tirúa', 'Lumaco'),
#  ('Tirúa', 'Vilcún'),
#  ('Tirúa', 'Valdivia'),
#  ('Tirúa', 'Futaleufú'),
#  ('Tirúa', 'Curarrehue'),
#  ('Tirúa', 'Jacobacci'),
#  ('Tirúa', 'Picunches'),
#  ('Tirúa', 'Lanco'),
#  ('Tirúa', 'Aluminé'),
#  ('Tirúa', 'Lonquimay'),
#  ('Tirúa', 'Angol'),
#  ('Tirúa', 'Cushamen'),
#  ('Tirúa', 'Truf Truf'),
#  ('Tirúa', 'San Pablo'),
#  ('S. Juan de la Costa', 'Icalma'),
#  ('S. Juan de la Costa', 'Huiliches'),
#  ('S. Juan de la Costa', 'Villarrica'),
#  ('S. Juan de la Costa', 'Ercilla'),
#  ('S. Juan de la Costa', 'Chol Chol'),
#  ('S. Juan de la Costa', 'Cañete'),
#  ('S. Juan de la Costa', 'Cunco'),
#  ('S. Juan de la Costa', 'Ref. Spelling'),
#  ('S. Juan de la Costa', 'Chalileo'),
#  ('S. Juan de la Costa', 'Galvarino'),
#  ('S. Juan de la Costa', 'Puerto Saavedra'),
#  ('S. Juan de la Costa', 'Junín de los Andes'),
#  ('S. Juan de la Costa', 'Panguipulli'),
#  ('S. Juan de la Costa', 'Freire'),
#  ('S. Juan de la Costa', 'Alto Bío Bío'),
#  ('S. Juan de la Costa', 'Dollinco'),
#  ('S. Juan de la Costa', 'Nueva Toltén'),
#  ('S. Juan de la Costa', 'Victoria'),
#  ('S. Juan de la Costa', 'Lago Rosario'),
#  ('S. Juan de la Costa', 'Zapala'),
#  ('S. Juan de la Costa', 'Santa Bárbara'),
#  ('S. Juan de la Costa', 'Mariquina'),
#  ('S. Juan de la Costa', 'Tirúa'),
#  ('S. Juan de la Costa', 'S. Juan de la Costa'),
#  ('S. Juan de la Costa', 'Lumaco'),
#  ('S. Juan de la Costa', 'Vilcún'),
#  ('S. Juan de la Costa', 'Valdivia'),
#  ('S. Juan de la Costa', 'Futaleufú'),
#  ('S. Juan de la Costa', 'Curarrehue'),
#  ('S. Juan de la Costa', 'Jacobacci'),
#  ('S. Juan de la Costa', 'Picunches'),
#  ('S. Juan de la Costa', 'Lanco'),
#  ('S. Juan de la Costa', 'Aluminé'),
#  ('S. Juan de la Costa', 'Lonquimay'),
#  ('S. Juan de la Costa', 'Angol'),
#  ('S. Juan de la Costa', 'Cushamen'),
#  ('S. Juan de la Costa', 'Truf Truf'),
#  ('S. Juan de la Costa', 'San Pablo'),
#  ('Lumaco', 'Icalma'),
#  ('Lumaco', 'Huiliches'),
#  ('Lumaco', 'Villarrica'),
#  ('Lumaco', 'Ercilla'),
#  ('Lumaco', 'Chol Chol'),
#  ('Lumaco', 'Cañete'),
#  ('Lumaco', 'Cunco'),
#  ('Lumaco', 'Ref. Spelling'),
#  ('Lumaco', 'Chalileo'),
#  ('Lumaco', 'Galvarino'),
#  ('Lumaco', 'Puerto Saavedra'),
#  ('Lumaco', 'Junín de los Andes'),
#  ('Lumaco', 'Panguipulli'),
#  ('Lumaco', 'Freire'),
#  ('Lumaco', 'Alto Bío Bío'),
#  ('Lumaco', 'Dollinco'),
#  ('Lumaco', 'Nueva Toltén'),
#  ('Lumaco', 'Victoria'),
#  ('Lumaco', 'Lago Rosario'),
#  ('Lumaco', 'Zapala'),
#  ('Lumaco', 'Santa Bárbara'),
#  ('Lumaco', 'Mariquina'),
#  ('Lumaco', 'Tirúa'),
#  ('Lumaco', 'S. Juan de la Costa'),
#  ('Lumaco', 'Lumaco'),
#  ('Lumaco', 'Vilcún'),
#  ('Lumaco', 'Valdivia'),
#  ('Lumaco', 'Futaleufú'),
#  ('Lumaco', 'Curarrehue'),
#  ('Lumaco', 'Jacobacci'),
#  ('Lumaco', 'Picunches'),
#  ('Lumaco', 'Lanco'),
#  ('Lumaco', 'Aluminé'),
#  ('Lumaco', 'Lonquimay'),
#  ('Lumaco', 'Angol'),
#  ('Lumaco', 'Cushamen'),
#  ('Lumaco', 'Truf Truf'),
#  ('Lumaco', 'San Pablo'),
#  ('Vilcún', 'Icalma'),
#  ('Vilcún', 'Huiliches'),
#  ('Vilcún', 'Villarrica'),
#  ('Vilcún', 'Ercilla'),
#  ('Vilcún', 'Chol Chol'),
#  ('Vilcún', 'Cañete'),
#  ('Vilcún', 'Cunco'),
#  ('Vilcún', 'Ref. Spelling'),
#  ('Vilcún', 'Chalileo'),
#  ('Vilcún', 'Galvarino'),
#  ('Vilcún', 'Puerto Saavedra'),
#  ('Vilcún', 'Junín de los Andes'),
#  ('Vilcún', 'Panguipulli'),
#  ('Vilcún', 'Freire'),
#  ('Vilcún', 'Alto Bío Bío'),
#  ('Vilcún', 'Dollinco'),
#  ('Vilcún', 'Nueva Toltén'),
#  ('Vilcún', 'Victoria'),
#  ('Vilcún', 'Lago Rosario'),
#  ('Vilcún', 'Zapala'),
#  ('Vilcún', 'Santa Bárbara'),
#  ('Vilcún', 'Mariquina'),
#  ('Vilcún', 'Tirúa'),
#  ('Vilcún', 'S. Juan de la Costa'),
#  ('Vilcún', 'Lumaco'),
#  ('Vilcún', 'Vilcún'),
#  ('Vilcún', 'Valdivia'),
#  ('Vilcún', 'Futaleufú'),
#  ('Vilcún', 'Curarrehue'),
#  ('Vilcún', 'Jacobacci'),
#  ('Vilcún', 'Picunches'),
#  ('Vilcún', 'Lanco'),
#  ('Vilcún', 'Aluminé'),
#  ('Vilcún', 'Lonquimay'),
#  ('Vilcún', 'Angol'),
#  ('Vilcún', 'Cushamen'),
#  ('Vilcún', 'Truf Truf'),
#  ('Vilcún', 'San Pablo'),
#  ('Valdivia', 'Icalma'),
#  ('Valdivia', 'Huiliches'),
#  ('Valdivia', 'Villarrica'),
#  ('Valdivia', 'Ercilla'),
#  ('Valdivia', 'Chol Chol'),
#  ('Valdivia', 'Cañete'),
#  ('Valdivia', 'Cunco'),
#  ('Valdivia', 'Ref. Spelling'),
#  ('Valdivia', 'Chalileo'),
#  ('Valdivia', 'Galvarino'),
#  ('Valdivia', 'Puerto Saavedra'),
#  ('Valdivia', 'Junín de los Andes'),
#  ...]

# %%
## aquí guardas las distancias

distancias = {L:{LL:0 for LL in list(dict_datos.keys())} for L in list(dict_datos.keys())}

# %%
# !pip install jellyfish
# Out:
# Requirement already satisfied: jellyfish in c:\users\jxver\anaconda3\lib\site-packages (0.8.8)

# %%
import jellyfish

def funcion_distancia(string1,string2):
    #return 1-jellyfish.jaro_winkler_similarity(string1,string2)
    alignment = nw(string1,string2).split('\n')
    string1 = alignment[0]
    string2 = alignment[1]
    return jellyfish.levenshtein_distance(string1,string2)/(max(len(string1),len(string2)))

# %%
## tienes q recorrer pares_localidades

for par in pares_localidades:
    D = 0
    words1 = dict_datos[par[0]]
    words2 = dict_datos[par[1]]
    words1and2 = list(set(words1) & set(words2))
    for word in words1and2:
        D += funcion_distancia(dict_datos[par[0]][word],dict_datos[par[1]][word])
    distancias[par[0]][par[1]]=D/len(words1and2)

# %%
dict(sorted(distancias['Chol Chol'].items(), key=lambda item: item[1]))
# Out:
# {'Chol Chol': 0.0,
#  'Cañete': 0.0,
#  'Galvarino': 0.0,
#  'Puerto Saavedra': 0.0,
#  'Panguipulli': 0.0,
#  'Freire': 0.0,
#  'Victoria': 0.0,
#  'Vilcún': 0.0,
#  'Valdivia': 0.0,
#  'Curarrehue': 0.0,
#  'Angol': 0.0,
#  'San Pablo': 0.0,
#  'Mariquina': 0.125,
#  'Tirúa': 0.125,
#  'Lumaco': 0.125,
#  'Ercilla': 0.2222222222222222,
#  'Cunco': 0.2222222222222222,
#  'Chalileo': 0.2222222222222222,
#  'Lago Rosario': 0.2222222222222222,
#  'Santa Bárbara': 0.2222222222222222,
#  'Cushamen': 0.2222222222222222,
#  'Nueva Toltén': 0.3,
#  'Aluminé': 0.3,
#  'Alto Bío Bío': 0.3333333333333333,
#  'Zapala': 0.3333333333333333,
#  'Futaleufú': 0.3333333333333333,
#  'Ref. Spelling': 0.375,
#  'Lanco': 0.375,
#  'Dollinco': 0.4,
#  'Jacobacci': 0.4,
#  'Truf Truf': 0.4,
#  'Lonquimay': 0.4166666666666667,
#  'Icalma': 0.4444444444444444,
#  'Junín de los Andes': 0.4444444444444444,
#  'Picunches': 0.4444444444444444,
#  'Huiliches': 0.45454545454545453,
#  'Villarrica': 0.45454545454545453,
#  'S. Juan de la Costa': 0.5}

# %%
DF = pd.DataFrame.from_dict(distancias)

# %%
DF
# Out:
#                        Icalma  Huiliches  Villarrica   Ercilla  Chol Chol  \
# Icalma               0.000000   0.131746    0.088095  0.209503   0.149263
# Huiliches            0.131746   0.000000    0.144426  0.235297   0.119032
# Villarrica           0.088095   0.144426    0.000000  0.230790   0.153358
# Ercilla              0.209503   0.235297    0.230790  0.000000   0.233936
# Chol Chol            0.149263   0.119032    0.153358  0.233936   0.000000
# Cañete               0.282261   0.315613    0.266059  0.364092   0.282200
# Cunco                0.243341   0.228146    0.229853  0.287706   0.192800
# Ref. Spelling        0.397846   0.428231    0.391071  0.450894   0.424972
# Chalileo             0.164768   0.158787    0.136111  0.241819   0.180272
# Galvarino            0.186116   0.213533    0.220027  0.253041   0.183078
# Puerto Saavedra      0.163549   0.204350    0.197008  0.241703   0.171088
# Junín de los Andes   0.169898   0.111660    0.211281  0.286459   0.172137
# Panguipulli          0.256215   0.286663    0.294834  0.279911   0.270529
# Freire               0.098271   0.153754    0.130540  0.198931   0.129280
# Alto Bío Bío         0.196344   0.193169    0.183645  0.238854   0.234864
# Dollinco             0.163095   0.136111    0.154167  0.238925   0.151984
# Nueva Toltén         0.226927   0.280308    0.230215  0.316039   0.272024
# Victoria             0.161887   0.168110    0.194805  0.250178   0.147279
# Lago Rosario         0.117491   0.111905    0.125488  0.221465   0.106916
# Zapala               0.137562   0.169700    0.136454  0.292270   0.167659
# Santa Bárbara        0.228244   0.289554    0.214409  0.310269   0.283673
# Mariquina            0.289146   0.344527    0.298051  0.286714   0.296315
# Tirúa                0.371585   0.381705    0.329696  0.367842   0.326317
# S. Juan de la Costa  0.362939   0.403806    0.355718  0.402172   0.371153
# Lumaco               0.329365   0.387487    0.316582  0.372580   0.326701
# Vilcún               0.149464   0.186776    0.150076  0.230365   0.152494
# Valdivia             0.228373   0.291793    0.214865  0.286820   0.253005
# Futaleufú            0.285807   0.279718    0.277871  0.363868   0.266043
# Curarrehue           0.141446   0.097458    0.113969  0.226595   0.100242
# Jacobacci            0.145413   0.151793    0.103914  0.270444   0.148526
# Picunches            0.188162   0.212369    0.226010  0.305393   0.204772
# Lanco                0.249278   0.248196    0.204095  0.378788   0.235299
# Aluminé              0.223276   0.193821    0.196771  0.319764   0.190193
# Lonquimay            0.226563   0.268282    0.242306  0.309955   0.258390
# Angol                0.155471   0.199956    0.180427  0.250745   0.177891
# Cushamen             0.152579   0.169643    0.144246  0.241901   0.141015
# Truf Truf            0.165051   0.173024    0.178345  0.280762   0.200368
# San Pablo            0.404932   0.423851    0.373624  0.423109   0.371202
#
#                        Cañete     Cunco  Ref. Spelling  Chalileo  Galvarino  \
# Icalma               0.282261  0.243341       0.397846  0.164768   0.186116
# Huiliches            0.315613  0.228146       0.428231  0.158787   0.213533
# Villarrica           0.266059  0.229853       0.391071  0.136111   0.220027
# Ercilla              0.364092  0.287706       0.450894  0.241819   0.253041
# Chol Chol            0.282200  0.192800       0.424972  0.180272   0.183078
# Cañete               0.000000  0.349954       0.418066  0.308542   0.212539
# Cunco                0.349954  0.000000       0.447996  0.192410   0.299263
# Ref. Spelling        0.418066  0.447996       0.000000  0.427664   0.398650
# Chalileo             0.308542  0.192410       0.427664  0.000000   0.237567
# Galvarino            0.212539  0.299263       0.398650  0.237567   0.000000
# Puerto Saavedra      0.284417  0.204531       0.380414  0.240505   0.170840
# Junín de los Andes   0.369571  0.277409       0.464229  0.232965   0.261791
# Panguipulli          0.205195  0.327618       0.426786  0.308555   0.154636
# Freire               0.275966  0.234304       0.376587  0.187528   0.107656
# Alto Bío Bío         0.286961  0.284609       0.425765  0.198810   0.180556
# Dollinco             0.307046  0.164990       0.377778  0.176162   0.223391
# Nueva Toltén         0.306493  0.323951       0.430272  0.289713   0.176873
# Victoria             0.274307  0.237960       0.414286  0.171797   0.200113
# Lago Rosario         0.296351  0.168396       0.431441  0.110976   0.197885
# Zapala               0.290505  0.164598       0.364976  0.155226   0.248554
# Santa Bárbara        0.203919  0.294734       0.409580  0.222761   0.156122
# Mariquina            0.310328  0.357710       0.451864  0.324638   0.199065
# Tirúa                0.271568  0.408119       0.500403  0.353114   0.255092
# S. Juan de la Costa  0.302690  0.433199       0.456759  0.403693   0.249611
# Lumaco               0.317548  0.389037       0.461310  0.376757   0.248029
# Vilcún               0.296014  0.210516       0.415781  0.187336   0.184240
# Valdivia             0.218290  0.326991       0.438051  0.283965   0.117100
# Futaleufú            0.409859  0.183218       0.490293  0.284369   0.359928
# Curarrehue           0.285498  0.216638       0.416239  0.121086   0.207243
# Jacobacci            0.280764  0.203600       0.395362  0.146609   0.245692
# Picunches            0.360083  0.313598       0.461240  0.216989   0.269818
# Lanco                0.247080  0.297405       0.418592  0.260823   0.252391
# Aluminé              0.331499  0.205584       0.429473  0.223763   0.271570
# Lonquimay            0.245031  0.352294       0.458719  0.300425   0.169112
# Angol                0.266758  0.244072       0.429705  0.200113   0.163640
# Cushamen             0.265590  0.159694       0.377778  0.167942   0.255612
# Truf Truf            0.288500  0.240511       0.402069  0.230697   0.214657
# San Pablo            0.356539  0.357620       0.541695  0.381888   0.296520
#
#                      ...  Curarrehue  Jacobacci  Picunches     Lanco  \
# Icalma               ...    0.141446   0.145413   0.188162  0.249278
# Huiliches            ...    0.097458   0.151793   0.212369  0.248196
# Villarrica           ...    0.113969   0.103914   0.226010  0.204095
# Ercilla              ...    0.226595   0.270444   0.305393  0.378788
# Chol Chol            ...    0.100242   0.148526   0.204772  0.235299
# Cañete               ...    0.285498   0.280764   0.360083  0.247080
# Cunco                ...    0.216638   0.203600   0.313598  0.297405
# Ref. Spelling        ...    0.416239   0.395362   0.461240  0.418592
# Chalileo             ...    0.121086   0.146609   0.216989  0.260823
# Galvarino            ...    0.207243   0.245692   0.269818  0.252391
# Puerto Saavedra      ...    0.202806   0.187620   0.268143  0.295368
# Junín de los Andes   ...    0.152263   0.198441   0.203610  0.309650
# Panguipulli          ...    0.258880   0.276989   0.366053  0.287868
# Freire               ...    0.136094   0.187758   0.218432  0.254265
# Alto Bío Bío         ...    0.166667   0.212868   0.287255  0.265940
# Dollinco             ...    0.169416   0.108992   0.217473  0.254240
# Nueva Toltén         ...    0.283135   0.302383   0.301103  0.292161
# Victoria             ...    0.152780   0.217216   0.219841  0.298016
# Lago Rosario         ...    0.113577   0.119087   0.184286  0.232223
# Zapala               ...    0.135815   0.079563   0.203360  0.211348
# Santa Bárbara        ...    0.270548   0.275353   0.323838  0.234949
# Mariquina            ...    0.324348   0.356669   0.388804  0.340108
# Tirúa                ...    0.343805   0.377353   0.429187  0.357561
# S. Juan de la Costa  ...    0.391819   0.412838   0.421429  0.376050
# Lumaco               ...    0.365600   0.364118   0.378391  0.348114
# Vilcún               ...    0.150340   0.196712   0.252675  0.275010
# Valdivia             ...    0.254716   0.281862   0.342666  0.232156
# Futaleufú            ...    0.283061   0.227134   0.284691  0.315244
# Curarrehue           ...    0.000000   0.126603   0.225612  0.227973
# Jacobacci            ...    0.126603   0.000000   0.211835  0.187680
# Picunches            ...    0.225612   0.211835   0.000000  0.329759
# Lanco                ...    0.227973   0.187680   0.329759  0.000000
# Aluminé              ...    0.202963   0.132823   0.262827  0.254545
# Lonquimay            ...    0.245493   0.253500   0.338394  0.255700
# Angol                ...    0.178288   0.232319   0.248131  0.267732
# Cushamen             ...    0.137799   0.095720   0.235101  0.212482
# Truf Truf            ...    0.213588   0.192746   0.279837  0.252110
# San Pablo            ...    0.409864   0.420309   0.484008  0.384345
#
#                       Aluminé  Lonquimay     Angol  Cushamen  Truf Truf  \
# Icalma               0.223276   0.226563  0.155471  0.152579   0.165051
# Huiliches            0.193821   0.268282  0.199956  0.169643   0.173024
# Villarrica           0.196771   0.242306  0.180427  0.144246   0.178345
# Ercilla              0.319764   0.309955  0.250745  0.241901   0.280762
# Chol Chol            0.190193   0.258390  0.177891  0.141015   0.200368
# Cañete               0.331499   0.245031  0.266758  0.265590   0.288500
# Cunco                0.205584   0.352294  0.244072  0.159694   0.240511
# Ref. Spelling        0.429473   0.458719  0.429705  0.377778   0.402069
# Chalileo             0.223763   0.300425  0.200113  0.167942   0.230697
# Galvarino            0.271570   0.169112  0.163640  0.255612   0.214657
# Puerto Saavedra      0.192013   0.236338  0.152636  0.177806   0.216808
# Junín de los Andes   0.249121   0.311566  0.263492  0.235771   0.224802
# Panguipulli          0.326113   0.201003  0.230906  0.270784   0.244903
# Freire               0.227922   0.189443  0.112103  0.182766   0.176446
# Alto Bío Bío         0.308362   0.219615  0.184864  0.211763   0.206576
# Dollinco             0.154145   0.299135  0.180357  0.136366   0.170679
# Nueva Toltén         0.343029   0.252494  0.203053  0.310317   0.275198
# Victoria             0.225085   0.284436  0.176051  0.191667   0.220697
# Lago Rosario         0.166876   0.260599  0.162552  0.128090   0.189349
# Zapala               0.140051   0.277268  0.222200  0.102466   0.182627
# Santa Bárbara        0.336310   0.216988  0.221601  0.274518   0.274541
# Mariquina            0.402268   0.273777  0.262046  0.357937   0.346500
# Tirúa                0.452252   0.326796  0.349557  0.382354   0.357830
# S. Juan de la Costa  0.430166   0.291957  0.347598  0.387567   0.366531
# Lumaco               0.425237   0.324098  0.304989  0.367587   0.357068
# Vilcún               0.238662   0.230612  0.149060  0.189796   0.225233
# Valdivia             0.324804   0.207817  0.216837  0.294388   0.277608
# Futaleufú            0.246380   0.389887  0.345236  0.239257   0.293290
# Curarrehue           0.202963   0.245493  0.178288  0.137799   0.213588
# Jacobacci            0.132823   0.253500  0.232319  0.095720   0.192746
# Picunches            0.262827   0.338394  0.248131  0.235101   0.279837
# Lanco                0.254545   0.255700  0.267732  0.212482   0.252110
# Aluminé              0.000000   0.326899  0.281838  0.163861   0.215762
# Lonquimay            0.326899   0.000000  0.236338  0.287384   0.262402
# Angol                0.281838   0.236338  0.000000  0.234354   0.200454
# Cushamen             0.163861   0.287384  0.234354  0.000000   0.180203
# Truf Truf            0.215762   0.262402  0.200454  0.180203   0.000000
# San Pablo            0.377728   0.386802  0.349093  0.391043   0.397513
#
#                      San Pablo
# Icalma                0.404932
# Huiliches             0.423851
# Villarrica            0.373624
# Ercilla               0.423109
# Chol Chol             0.371202
# Cañete                0.356539
# Cunco                 0.357620
# Ref. Spelling         0.541695
# Chalileo              0.381888
# Galvarino             0.296520
# Puerto Saavedra       0.314512
# Junín de los Andes    0.452958
# Panguipulli           0.370784
# Freire                0.342942
# Alto Bío Bío          0.362812
# Dollinco              0.384439
# Nueva Toltén          0.324821
# Victoria              0.393831
# Lago Rosario          0.364225
# Zapala                0.414321
# Santa Bárbara         0.325778
# Mariquina             0.348276
# Tirúa                 0.354344
# S. Juan de la Costa   0.321032
# Lumaco                0.380896
# Vilcún                0.323313
# Valdivia              0.318602
# Futaleufú             0.460694
# Curarrehue            0.409864
# Jacobacci             0.420309
# Picunches             0.484008
# Lanco                 0.384345
# Aluminé               0.377728
# Lonquimay             0.386802
# Angol                 0.349093
# Cushamen              0.391043
# Truf Truf             0.397513
# San Pablo             0.000000
#
# [38 rows x 38 columns]

# %%
DF.to_excel('distancias.xlsx')

# %%
## construyamos un heatmap :) https://seaborn.pydata.org/generated/seaborn.heatmap.html

import seaborn as sns
import scipy.spatial as sp, scipy.cluster.hierarchy as hc
import matplotlib.pyplot as plt
import numpy as np

def mapa_calor(D):
    
    
    linkage = hc.linkage(sp.distance.squareform(DF), method='ward')
        
    plt.figure(figsize=(10,10))
    cg=sns.clustermap(D,cmap='OrRd',row_linkage=linkage, col_linkage=linkage,linewidth=1,yticklabels=True,xticklabels=True,cbar_kws={'shrink': 0.3})
       
    plt.rcParams.update({'font.size': 12})
    #plt.savefig('heatmap.jpg', format='jpg', transparent=True, bbox_inches='tight',dpi=800)

# %%
mapa_calor(distancias)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-254-8b1833e1465f> in <module>
# ----> 1 mapa_calor(distancias)
#
# <ipython-input-253-cb6bae143ada> in mapa_calor(D)
#       9
#      10
# ---> 11     linkage = hc.linkage(sp.distance.squareform(DF), method='ward')
#      12
#      13     plt.figure(figsize=(10,10))
#
# ~\anaconda3\lib\site-packages\scipy\spatial\distance.py in squareform(X, force, checks)
#    2213             raise ValueError('The matrix argument must be square.')
#    2214         if checks:
# -> 2215             is_valid_dm(X, throw=True, name='X')
#    2216
#    2217         # One-side of the dimensions is set here.
#
# ~\anaconda3\lib\site-packages\scipy\spatial\distance.py in is_valid_dm(D, tol, throw, name, warning)
#    2288             if not (D == D.T).all():
#    2289                 if name:
# -> 2290                     raise ValueError(('Distance matrix \'%s\' must be '
#    2291                                      'symmetric.') % name)
#    2292                 else:
#
# ValueError: Distance matrix 'X' must be symmetric.

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

labels_dict = {}

range_n_clusters = [2, 3, 4, 5, 6, 7, 8, 9, 10]
S = []
for n_clusters in range_n_clusters:
    
    cluster = KMeans(n_clusters=n_clusters)#, linkage='ward')
    distArray = sp.distance.squareform(DF.to_numpy())
    cluster_labels = cluster.fit_predict(DF.values)
    labels_dict[n_clusters]=cluster_labels
    silhouette_avg = silhouette_score(DF.values, cluster_labels, metric = 'precomputed')
    S.append(silhouette_avg)
    print("For n_clusters =", n_clusters,"The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.2815967199263774
# For n_clusters = 3 The average silhouette_score is : 0.21095615185928318
# For n_clusters = 4 The average silhouette_score is : 0.1005812906379821
# For n_clusters = 5 The average silhouette_score is : 0.16450661554367252
# For n_clusters = 6 The average silhouette_score is : 0.08215341895174555
# For n_clusters = 7 The average silhouette_score is : 0.024783478257200703
# For n_clusters = 8 The average silhouette_score is : 0.1005809334924887
# For n_clusters = 9 The average silhouette_score is : 0.060479976243193845
# For n_clusters = 10 The average silhouette_score is : 0.06906079185743802
